# %%
import pandas as pd
import isbnlib
import sys
import os

current_dir = os.path.abspath('')
parent_dir = os.path.join(current_dir, '..', 'functions')
sys.path.append(parent_dir)

from isbn_utils import contain_isbn13
from duplicates_utils import number_of_duplicates
from lang_utils import contain_lang

# %% [markdown]
# IMPORT DATA

# %%
path = "../../dataset/origin/dataset.csv"
df = pd.read_csv(path, sep=",", encoding="cp1250", encoding_errors="replace")

df = df.replace({"[\u2028\u2029]": ""}, regex=True)
df
# Out:
#                  authors  bestsellers-rank  \
# 0                    [1]           49848.0
# 1                 [2, 3]          115215.0
# 2                    [4]           11732.0
# 3           [5, 6, 7, 8]          114379.0
# 4                    [9]           98413.0
# ...                  ...               ...
# 1109378         [120629]               NaN
# 1109379         [336369]               NaN
# 1109380  [29792, 654019]               NaN
# 1109381         [654020]               NaN
# 1109382         [654021]               NaN
#
#                                             categories  \
# 0        [214, 220, 237, 2646, 2647, 2659, 2660, 2679]
# 1                                          [235, 3386]
# 2                               [358, 2630, 360, 2632]
# 3                                    [377, 2978, 2980]
# 4                                         [2813, 2980]
# ...                                                ...
# 1109378                                         [3055]
# 1109379                       [3045, 3054, 3068, 3086]
# 1109380                                         [3096]
# 1109381                                   [3054, 3056]
# 1109382                             [3002, 3055, 3056]
#
#                                                description  dimension-x  \
# 0        SOLDIER FIVE is an elite soldier's explosive m...       129.00
# 1        John Moran and Carl Williams were the two bigg...       127.00
# 2        Sir Phillip knew that Eloise Bridgerton was a ...       150.00
# 3        The Third Book of General Ignorance  gathers t...       153.00
# 4        The Try Guys deliver their first book-an inspi...       191.00
# ...                                                    ...          ...
# 1109378                                                NaN       140.00
# 1109379  This 2020 Diary/Planner has one week per 2 pag...       151.89
# 1109380  This special re-print edition of James A. Crui...       216.00
# 1109381  Good western riding doesn't just happen. J.P. ...       222.00
# 1109382  This complete guide tells how to develop the h...       162.00
#
#          dimension-y  dimension-z      edition    edition-statement for-ages  \
# 0             198.00        20.00          NaN                  NaN      NaN
# 1             203.20        25.40          NaN                  NaN      NaN
# 2             224.00        28.00  New edition                  NaN      NaN
# 3             234.00        24.00          NaN  Export - Airside ed      NaN
# 4             240.00        29.00          NaN                  NaN      NaN
# ...              ...          ...          ...                  ...      ...
# 1109378       216.00         6.00          NaN                  NaN      NaN
# 1109379       229.11         7.11          NaN                  NaN      NaN
# 1109380       279.00         8.00          NaN                  NaN      NaN
# 1109381       287.00        19.05          NaN                  NaN      NaN
# 1109382       241.00        19.05          NaN                  NaN      NaN
#
#          ...      isbn10         isbn13 lang     publication-date  \
# 0        ...  184018907X  9781840189070   en  2004-10-14 00:00:00
# 1        ...  184454737X  9781844547371   en  2009-03-13 00:00:00
# 2        ...  8416327866  9788416327867   es  2020-04-30 00:00:00
# 3        ...   571308996  9780571308996   en  2015-10-01 00:00:00
# 4        ...     8352518  9780008352516   en  2019-06-18 00:00:00
# ...      ...         ...            ...  ...                  ...
# 1109378  ...   879802685  9780879802684   en  1980-12-01 00:00:00
# 1109379  ...  1711791962  9781711791968   en  2019-11-25 00:00:00
# 1109380  ...  1792858019  9781792858017   en  2018-12-28 00:00:00
# 1109381  ...   876059825  9780876059821   en  1995-04-12 00:00:00
# 1109382  ...   876059655  9780876059654   en  1993-10-01 00:00:00
#
#         publication-place rating-avg rating-count  \
# 0                     NaN       4.03        292.0
# 1                     NaN       3.60        335.0
# 2                     NaN       3.88      37211.0
# 3                     NaN       4.17        384.0
# 4                     NaN       3.90       5095.0
# ...                   ...        ...          ...
# 1109378               NaN        NaN          NaN
# 1109379               NaN        NaN          NaN
# 1109380               NaN        NaN          NaN
# 1109381               NaN        NaN          NaN
# 1109382               NaN        NaN          NaN
#
#                                                      title  \
# 0        Soldier Five : The Real Truth About The Bravo ...
# 1                            Underbelly : The Gangland War
# 2                                  A Sir Phillip, Con Amor
# 3                  QI: The Third Book of General Ignorance
# 4                           The Hidden Power of F*cking Up
# ...                                                    ...
# 1109378                          Making Money at the Races
# 1109379  2020 : Diary, Weekly Planner, Organiser, Year ...
# 1109380                               Canoeing and Camping
# 1109381  The Complete Guide to Western Horsemanship (Cl...
# 1109382  Show Ring Success : A Rider's Guide to Winning...
#
#                                                        url  weight
# 0                  /Soldier-Five-Mike-Coburn/9781840189070  224.00
# 1                    /Underbelly-Andrew-Rule/9781844547371  285.76
# 2          /Sir-Phillip-Con-Amor-Julia-Quinn/9788416327867  386.00
# 3        /QI-Third-Book-General-Ignorance-John-Lloyd/97...  436.00
# 4          /Hidden-Power-F-cking-Up-Try-Guys/9780008352516  980.00
# ...                                                    ...     ...
# 1109378    /Making-Money-at-Races-David-Barr/9780879802684  227.00
# 1109379             /2020-Annie-Mac-Journals/9781711791968  185.97
# 1109380   /Canoeing-Camping-James-Cruikshank/9781792858017  372.00
# 1109381  /Complete-Guide-Western-Horsemanship-Cloth-For...  916.00
# 1109382  /Show-Ring-Success-Kathleen-Obenland/978087605...  476.00
#
# [1109383 rows x 28 columns]

# %% [markdown]
# ADD ID COLUMN

# %%
df['id'] = range(1, len(df) + 1)

# %% [markdown]
# DROP DUPLICATES

# %%
number_of_duplicates(df)
# Out:
# 0

# %% [markdown]
# DROP COLUMNS

# %%
drop_columns = ['index-date','illustrations-note','image-checksum','image-path','image-url','publication-place',
                'url','edition','imprint','edition-statement']
df = df.drop(columns = drop_columns)

# %% [markdown]
# CLEAN DATA

# %%
#shows how many rows has only isbn10 value
filtered_df = df[df['isbn10'].notna() & df['isbn13'].isna()]
filtered_df
# Out:
# Empty DataFrame
# Columns: [authors, bestsellers-rank, categories, description, dimension-x, dimension-y, dimension-z, for-ages, format, id, isbn10, isbn13, lang, publication-date, rating-avg, rating-count, title, weight]
# Index: []

# %%
#validate isbn13 values
df['isbn13_valid'] = contain_isbn13(df['isbn13'])
df['isbn13_valid'].unique()
# Out:
# array([ True])

# %%
df['lang_valid'] = contain_lang(df['lang'])
df['lang_valid'].unique()
# Out:
# array([ True, False])

# %%
valid_lang_rows = df[df['lang'].notna() & (df['lang_valid'] == False)]
valid_lang_rows
# Out:
# Empty DataFrame
# Columns: [authors, bestsellers-rank, categories, description, dimension-x, dimension-y, dimension-z, for-ages, format, id, isbn10, isbn13, lang, publication-date, rating-avg, rating-count, title, weight, isbn13_valid, lang_valid]
# Index: []

# %%
#Drop auxiliary columns
df = df.drop(columns = ['isbn10','isbn13_valid','lang_valid'])

# %% [markdown]
# DUPLICATES AFTER DATA CLEANING

# %%
number_of_duplicates(df['isbn13'])
# Out:
# 0

# %%
df
# Out:
#                  authors  bestsellers-rank  \
# 0                    [1]           49848.0
# 1                 [2, 3]          115215.0
# 2                    [4]           11732.0
# 3           [5, 6, 7, 8]          114379.0
# 4                    [9]           98413.0
# ...                  ...               ...
# 1109378         [120629]               NaN
# 1109379         [336369]               NaN
# 1109380  [29792, 654019]               NaN
# 1109381         [654020]               NaN
# 1109382         [654021]               NaN
#
#                                             categories  \
# 0        [214, 220, 237, 2646, 2647, 2659, 2660, 2679]
# 1                                          [235, 3386]
# 2                               [358, 2630, 360, 2632]
# 3                                    [377, 2978, 2980]
# 4                                         [2813, 2980]
# ...                                                ...
# 1109378                                         [3055]
# 1109379                       [3045, 3054, 3068, 3086]
# 1109380                                         [3096]
# 1109381                                   [3054, 3056]
# 1109382                             [3002, 3055, 3056]
#
#                                                description  dimension-x  \
# 0        SOLDIER FIVE is an elite soldier's explosive m...       129.00
# 1        John Moran and Carl Williams were the two bigg...       127.00
# 2        Sir Phillip knew that Eloise Bridgerton was a ...       150.00
# 3        The Third Book of General Ignorance  gathers t...       153.00
# 4        The Try Guys deliver their first book-an inspi...       191.00
# ...                                                    ...          ...
# 1109378                                                NaN       140.00
# 1109379  This 2020 Diary/Planner has one week per 2 pag...       151.89
# 1109380  This special re-print edition of James A. Crui...       216.00
# 1109381  Good western riding doesn't just happen. J.P. ...       222.00
# 1109382  This complete guide tells how to develop the h...       162.00
#
#          dimension-y  dimension-z for-ages  format       id         isbn13  \
# 0             198.00        20.00      NaN     1.0        1  9781840189070
# 1             203.20        25.40      NaN     1.0        2  9781844547371
# 2             224.00        28.00      NaN     1.0        3  9788416327867
# 3             234.00        24.00      NaN     1.0        4  9780571308996
# 4             240.00        29.00      NaN     2.0        5  9780008352516
# ...              ...          ...      ...     ...      ...            ...
# 1109378       216.00         6.00      NaN     1.0  1109379  9780879802684
# 1109379       229.11         7.11      NaN     1.0  1109380  9781711791968
# 1109380       279.00         8.00      NaN     1.0  1109381  9781792858017
# 1109381       287.00        19.05      NaN     2.0  1109382  9780876059821
# 1109382       241.00        19.05      NaN     2.0  1109383  9780876059654
#
#         lang     publication-date  rating-avg  rating-count  \
# 0         en  2004-10-14 00:00:00        4.03         292.0
# 1         en  2009-03-13 00:00:00        3.60         335.0
# 2         es  2020-04-30 00:00:00        3.88       37211.0
# 3         en  2015-10-01 00:00:00        4.17         384.0
# 4         en  2019-06-18 00:00:00        3.90        5095.0
# ...      ...                  ...         ...           ...
# 1109378   en  1980-12-01 00:00:00         NaN           NaN
# 1109379   en  2019-11-25 00:00:00         NaN           NaN
# 1109380   en  2018-12-28 00:00:00         NaN           NaN
# 1109381   en  1995-04-12 00:00:00         NaN           NaN
# 1109382   en  1993-10-01 00:00:00         NaN           NaN
#
#                                                      title  weight
# 0        Soldier Five : The Real Truth About The Bravo ...  224.00
# 1                            Underbelly : The Gangland War  285.76
# 2                                  A Sir Phillip, Con Amor  386.00
# 3                  QI: The Third Book of General Ignorance  436.00
# 4                           The Hidden Power of F*cking Up  980.00
# ...                                                    ...     ...
# 1109378                          Making Money at the Races  227.00
# 1109379  2020 : Diary, Weekly Planner, Organiser, Year ...  185.97
# 1109380                               Canoeing and Camping  372.00
# 1109381  The Complete Guide to Western Horsemanship (Cl...  916.00
# 1109382  Show Ring Success : A Rider's Guide to Winning...  476.00
#
# [1109383 rows x 17 columns]

# %% [markdown]
# DATA SPLIT

# %%
id = ['id']

addition_columns =['dimension-x','dimension-y','dimension-z','rating-avg',
                    'rating-count','weight','bestsellers-rank','for-ages']

columns = id + addition_columns


addition_data = df[columns].copy()
addition_data
df = df.drop(columns=addition_columns)

# %% [markdown]
# RENAME A FEW ADDITION_DATA COLUMNS AND CHANGE DATA TYPE

# %%
addition_data = addition_data.rename(columns={'id': 'book_id',
                                            'rating-count': 'rating_count',
                                            'dimension-x': 'dimension_x',
                                            'dimension-y': 'dimension_y',
                                            'dimension-z': 'dimension_z',
                                            'rating-avg': 'rating_avg',
                                            'bestsellers-rank': 'bestsellers_rank',
                                            'for-ages': 'for_ages'})

addition_data[["rating_count", "bestsellers_rank"]] = addition_data[
                        ["rating_count","bestsellers_rank"]].astype("Int64")
# Out:
#          book_id  dimension_x  dimension_y  dimension_z  rating_avg  \
# 0              1       129.00       198.00        20.00        4.03
# 1              2       127.00       203.20        25.40        3.60
# 2              3       150.00       224.00        28.00        3.88
# 3              4       153.00       234.00        24.00        4.17
# 4              5       191.00       240.00        29.00        3.90
# ...          ...          ...          ...          ...         ...
# 1109378  1109379       140.00       216.00         6.00         NaN
# 1109379  1109380       151.89       229.11         7.11         NaN
# 1109380  1109381       216.00       279.00         8.00         NaN
# 1109381  1109382       222.00       287.00        19.05         NaN
# 1109382  1109383       162.00       241.00        19.05         NaN
#
#          rating_count  weight  bestsellers_rank for_ages
# 0                 292  224.00             49848      NaN
# 1                 335  285.76            115215      NaN
# 2               37211  386.00             11732      NaN
# 3                 384  436.00            114379      NaN
# 4                5095  980.00             98413      NaN
# ...               ...     ...               ...      ...
# 1109378          <NA>  227.00              <NA>      NaN
# 1109379          <NA>  185.97              <NA>      NaN
# 1109380          <NA>  372.00              <NA>      NaN
# 1109381          <NA>  916.00              <NA>      NaN
# 1109382          <NA>  476.00              <NA>      NaN
#
# [1109383 rows x 9 columns]

# %% [markdown]
# EXPORT DAT

# %%
def clean_text(text):
    if isinstance(text, str):
        text = text.encode('utf-8', errors='ignore').decode('utf-8')
        text = text.replace('\u2028', ' ').replace('\u2029', ' ')
        text = ''.join(char for char in text if ord(char) < 128)
    return text

text_columns = ['title', 'description']
for col in text_columns:
    df[col] = df[col].apply(clean_text)

file_name = "dataset_cleaned.csv"
folder_path = "../../dataset/cleaned"
final_path = os.path.join(folder_path, file_name)
df.to_csv(final_path, encoding="utf-8", quoting=0, index=False, na_rep="",
           escapechar='\\')

# %%
file_name = "addition_cleaned.csv"
final_path = os.path.join(folder_path, file_name)
addition_data.to_csv(final_path, sep=",", encoding="utf-8", index=False)
